# %%
import tweepy 
import csv
import pandas as pd

# %%
#Twitter API credentials
consumer_key = ""
consumer_secret = ""
access_key = ""
access_secret = ""

# %%
def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method

    #authorize twitter, initialize tweepy
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    
    #initialize a list to hold all the tweepy Tweets
    alltweets = []
    
    #make initial request for most recent tweets (200 is the maximum allowed count)
    new_tweets = api.user_timeline(screen_name = screen_name,count=200)
    
    #save most recent tweets
    alltweets.extend(new_tweets)
    
    #save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1
    
    #keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 10:
        #all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
        
        #save most recent tweets
        alltweets.extend(new_tweets)
        
        #update the id of the oldest tweet less one
        oldest = alltweets[-1].id - 1
    return alltweets

# %%
if __name__ == '__main__':
    #pass in the username of the account you want to download
    handle = "sardesairajdeep"
    raw_data = get_all_tweets(handle)

# %%
outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8"),tweet.favorite_count,tweet.retweet_count] for tweet in raw_data]

# %%
import pickle
# dump the raw_data to outfile
name = 'outfile_'+handle
with open(name, 'wb') as fp:
    pickle.dump(raw_data, fp)

# %%
outtweets
# Out:
# [['919454574439813122',
#   datetime.datetime(2017, 10, 15, 6, 47, 7),
#   b'@jatingandhi which is precisely why any Cong celebration is premature.',
#   18,
#   4],
#  ['919449553224417280',
#   datetime.datetime(2017, 10, 15, 6, 27, 10),
#   b"Breaking: Cong wins Gurdaspur by election by 1.5 lakh margin.Don't think it will affect Himachal though: BJP frontrunner here #WarForThrones",
#   491,
#   126],
#  ['919419203924439041',
#   datetime.datetime(2017, 10, 15, 4, 26, 34),
#   b'How times change! Anil Sharma, son of Sukhram and minister in HP govt,\nSet to join BJP. In 1990s, Sukhram was a corruption mascot for BJP!\xf0\x9f\x91\x8d',
#   1185,
#   512],
#  ['919418117431988224',
#   datetime.datetime(2017, 10, 15, 4, 22, 15),
#   b'Yes, you are right! https://t.co/yNyddfT1Hn',
#   75,
#   19],
#  ['919417607995891712',
#   datetime.datetime(2017, 10, 15, 4, 20, 14),
#   b"Lovely one Ajit! Won't happen in India! Maybe with Manmohan Singh? https://t.co/K12WtSj9aU",
#   203,
# ...
